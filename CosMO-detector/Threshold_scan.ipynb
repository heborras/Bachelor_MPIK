# %% [markdown]
# # Threshold scanner

# %% [markdown]
# ### This python script can record arbitrary data from a serial connection. For a set time even. Please note that the outputted data is likely formatted in mac line endings (because that is what Arduinos send). So if you want to use the data in another program, especially the analysis program, conversion to Linux line endings must be done. On Windows Notepad++ can do this.
#
#
# Note: the maximum output speed of the DAQ-card is about 30 events per second

# %%
import serial
import time

# %%
# settings

recording_secs_per_setting = 60*2

start_threshold = 10
stop_threshold = 600
step_size = 10

detector_mode = "2E" # Coincidence (threefold) and Channels (1,2,3), no veto
#detector_mode = "2E" # Coincidence (threefold) and Channels (1,2,3), no veto

output_file = time.strftime("%Y%m%d-%H%M")+"_Thresh_scan"
output_file += "_start-"+str(start_threshold)+"_stop-"+str(stop_threshold)+"_step-"+str(step_size)
output_file += "_sec_per_rec_"+str(recording_secs_per_setting)
output_file += "_detector_mode_"+str(detector_mode)+".txt"
print("Output file name: " + output_file)
serial_port = 'COM14'
baud_rate = 115200
# Out:
# Output file name: 20171115-1444_Thresh_scan_start-10_stop-600_step-10_sec_per_rec_120_detector_mode_2E.txt

# %%
# start the serial connection
ser = serial.Serial(serial_port, baud_rate, timeout=0.5)

# %%
# Functions

def turn_off_auto_reset():
    commands = "ST 0\r"
    setting_successfull = False
    while setting_successfull == False:
        ser.write(commands)
        # check if everything was recieved as prompted
        curr_line = str(ser.readline())
        curr_line = str(ser.readline())
        checking_line = curr_line
        if "ST Disabled" in checking_line:
            setting_successfull = True
            print("Disabling of the auto reset was sucessfull")
            break
        else:
            print("Disabling of the auto reset mode failed! Retring now.")
            setting_successfull = False
            continue

def set_detector_mode(detector_mode):
    commands = "WC 00 "+detector_mode+"\r"
    setting_successfull = False
    while setting_successfull == False:
        ser.write(commands)
        # check if everything was recieved as prompted
        curr_line = str(ser.readline())
        curr_line = str(ser.readline())
        checking_line = curr_line
        returned_parameters = checking_line.split("=")
        result_setting = returned_parameters[1].replace('\r\n', '')
        if (result_setting == detector_mode):
            setting_successfull = True
            print("Setting of the coincidence mode was sucessfull")
            break
        else:
            print("Setting of the coincidence mode failed! Retring now.")
            setting_successfull = False
            continue
    

def set_thresh(threshs):
    setting_successfull = False
    while setting_successfull == False:
        commands = "TL 0 "+str(threshs[0])+"\rTL 1 "+str(threshs[1])+"\rTL 2 "+str(threshs[2])+"\rTL 3 "+str(threshs[3])+"\r"
        ser.write(commands)
        # poll until all commands were recieved
        curr_line = ser.readline()
        while not (curr_line == ''):
            curr_line = ser.readline()
        # check if everything was recieved as prompted
        ser.write("TL\r")
        curr_line = str(ser.readline())
        curr_line = str(ser.readline())
        checking_line = curr_line
        checking_line = checking_line.replace("L0","").replace("L1","").replace("L2","").replace("L3","")
        returned_parameters = checking_line.split("=")
        for i in range(len(threshs)):
            if(int(returned_parameters[i+1]) != int(threshs[i])):
                print("Setting of thresholds failed! Retring now.")
                setting_successfull = False
                continue
        setting_successfull = True
        print("Setting of thresholds was sucessfull. Set to: "+str(threshs))
        break
        
def stop_detector_output():
    # stop the output from the detector and poll last lines
    print("Stopping detector output")
    ser.write("CD\r")
    curr_line = ser.readline()
    while not (curr_line == ''):
        curr_line = ser.readline()
    print("Detector output stopped")

# %%
turn_off_auto_reset()
stop_detector_output()
# setup the detector
set_thresh([start_threshold for i in range(4)])
set_detector_mode(detector_mode)
# Out:
# Disabling of the auto reset was sucessfull
# Stopping detector output
# Detector output stopped
# Setting of thresholds was sucessfull. Set to: [10, 10, 10, 10]
# Setting of the coincidence mode was sucessfull

# %%
current_thresh = start_threshold
# write into output file
with open(output_file, 'w') as f:
    f.write("recording_secs_per_setting: "+str(recording_secs_per_setting)+"\r\r")
    while current_thresh <= stop_threshold:
        # set new thresholds
        set_thresh([current_thresh for i in range(4)])
        f.write("Current Threshold: "+str(current_thresh)+"\r\r")
        # reset the detector counters
        ser.write("RB\r")
        # start the timer
        start_time = time.time()
        # wait unit we can stop
        while time.time() < (start_time+recording_secs_per_setting):
            time.sleep(0.001)
        # read the counters
        ser.write("DS\r")
        # write lines into file:
        curr_line = ser.readline()
        while not (curr_line == ''):
            # remove the \n at the end
            curr_line = curr_line.split('\n')[0]
            f.write(curr_line)
            curr_line = ser.readline()
        f.flush()
        
        # increment the threshold
        current_thresh += step_size
        
        steps_left = (stop_threshold-current_thresh+step_size)/step_size
        time_left = recording_secs_per_setting * steps_left
        print("Estimated leftover runtime: {:.1f} [min]".format(time_left/60.0))
# Out:
# Setting of thresholds was sucessfull. Set to: [10, 10, 10, 10]
# Estimated leftover runtime: 118.0 [min]
# Setting of thresholds was sucessfull. Set to: [20, 20, 20, 20]
# Estimated leftover runtime: 116.0 [min]
# Setting of thresholds was sucessfull. Set to: [30, 30, 30, 30]
# Estimated leftover runtime: 114.0 [min]
# Setting of thresholds was sucessfull. Set to: [40, 40, 40, 40]
# Estimated leftover runtime: 112.0 [min]
# Setting of thresholds was sucessfull. Set to: [50, 50, 50, 50]
# Estimated leftover runtime: 110.0 [min]
# Setting of thresholds was sucessfull. Set to: [60, 60, 60, 60]
# Estimated leftover runtime: 108.0 [min]
# Setting of thresholds was sucessfull. Set to: [70, 70, 70, 70]
# Estimated leftover runtime: 106.0 [min]
# Setting of thresholds was sucessfull. Set to: [80, 80, 80, 80]
# Estimated leftover runtime: 104.0 [min]
# Setting of thresholds was sucessfull. Set to: [90, 90, 90, 90]
# Estimated leftover runtime: 102.0 [min]
# Setting of thresholds was sucessfull. Set to: [100, 100, 100, 100]
# Estimated leftover runtime: 100.0 [min]
# Setting of thresholds was sucessfull. Set to: [110, 110, 110, 110]
# Estimated leftover runtime: 98.0 [min]
# Setting of thresholds was sucessfull. Set to: [120, 120, 120, 120]
# Estimated leftover runtime: 96.0 [min]
# Setting of thresholds was sucessfull. Set to: [130, 130, 130, 130]
# Estimated leftover runtime: 94.0 [min]
# Setting of thresholds was sucessfull. Set to: [140, 140, 140, 140]
# Estimated leftover runtime: 92.0 [min]
# Setting of thresholds was sucessfull. Set to: [150, 150, 150, 150]
# Estimated leftover runtime: 90.0 [min]
# Setting of thresholds was sucessfull. Set to: [160, 160, 160, 160]
# Estimated leftover runtime: 88.0 [min]
# Setting of thresholds was sucessfull. Set to: [170, 170, 170, 170]
# Estimated leftover runtime: 86.0 [min]
# Setting of thresholds was sucessfull. Set to: [180, 180, 180, 180]
# Estimated leftover runtime: 84.0 [min]
# Setting of thresholds was sucessfull. Set to: [190, 190, 190, 190]
# Estimated leftover runtime: 82.0 [min]
# Setting of thresholds was sucessfull. Set to: [200, 200, 200, 200]
# Estimated leftover runtime: 80.0 [min]
# Setting of thresholds was sucessfull. Set to: [210, 210, 210, 210]
# Estimated leftover runtime: 78.0 [min]
# Setting of thresholds was sucessfull. Set to: [220, 220, 220, 220]
# Estimated leftover runtime: 76.0 [min]
# Setting of thresholds was sucessfull. Set to: [230, 230, 230, 230]
# Estimated leftover runtime: 74.0 [min]
# Setting of thresholds was sucessfull. Set to: [240, 240, 240, 240]
# Estimated leftover runtime: 72.0 [min]
# Setting of thresholds was sucessfull. Set to: [250, 250, 250, 250]
# Estimated leftover runtime: 70.0 [min]
# Setting of thresholds was sucessfull. Set to: [260, 260, 260, 260]
# Estimated leftover runtime: 68.0 [min]
# Setting of thresholds was sucessfull. Set to: [270, 270, 270, 270]
# Estimated leftover runtime: 66.0 [min]
# Setting of thresholds was sucessfull. Set to: [280, 280, 280, 280]
# Estimated leftover runtime: 64.0 [min]
# Setting of thresholds was sucessfull. Set to: [290, 290, 290, 290]
# Estimated leftover runtime: 62.0 [min]
# Setting of thresholds was sucessfull. Set to: [300, 300, 300, 300]
# Estimated leftover runtime: 60.0 [min]
# Setting of thresholds was sucessfull. Set to: [310, 310, 310, 310]
# Estimated leftover runtime: 58.0 [min]
# Setting of thresholds was sucessfull. Set to: [320, 320, 320, 320]
# Estimated leftover runtime: 56.0 [min]
# Setting of thresholds was sucessfull. Set to: [330, 330, 330, 330]
# Estimated leftover runtime: 54.0 [min]
# Setting of thresholds was sucessfull. Set to: [340, 340, 340, 340]
# Estimated leftover runtime: 52.0 [min]
# Setting of thresholds was sucessfull. Set to: [350, 350, 350, 350]
# Estimated leftover runtime: 50.0 [min]
# Setting of thresholds was sucessfull. Set to: [360, 360, 360, 360]
# Estimated leftover runtime: 48.0 [min]
# Setting of thresholds was sucessfull. Set to: [370, 370, 370, 370]
# Estimated leftover runtime: 46.0 [min]
# Setting of thresholds was sucessfull. Set to: [380, 380, 380, 380]
# Estimated leftover runtime: 44.0 [min]
# Setting of thresholds was sucessfull. Set to: [390, 390, 390, 390]
# Estimated leftover runtime: 42.0 [min]
# Setting of thresholds was sucessfull. Set to: [400, 400, 400, 400]
# Estimated leftover runtime: 40.0 [min]
# Setting of thresholds was sucessfull. Set to: [410, 410, 410, 410]
# Estimated leftover runtime: 38.0 [min]
# Setting of thresholds was sucessfull. Set to: [420, 420, 420, 420]
# Estimated leftover runtime: 36.0 [min]
# Setting of thresholds was sucessfull. Set to: [430, 430, 430, 430]
# Estimated leftover runtime: 34.0 [min]
# Setting of thresholds was sucessfull. Set to: [440, 440, 440, 440]
# Estimated leftover runtime: 32.0 [min]
# Setting of thresholds was sucessfull. Set to: [450, 450, 450, 450]
# Estimated leftover runtime: 30.0 [min]
# Setting of thresholds was sucessfull. Set to: [460, 460, 460, 460]
# Estimated leftover runtime: 28.0 [min]
# Setting of thresholds was sucessfull. Set to: [470, 470, 470, 470]
# Estimated leftover runtime: 26.0 [min]
# Setting of thresholds was sucessfull. Set to: [480, 480, 480, 480]
# Estimated leftover runtime: 24.0 [min]
# Setting of thresholds was sucessfull. Set to: [490, 490, 490, 490]
# Estimated leftover runtime: 22.0 [min]
# Setting of thresholds was sucessfull. Set to: [500, 500, 500, 500]
# Estimated leftover runtime: 20.0 [min]
# Setting of thresholds was sucessfull. Set to: [510, 510, 510, 510]
# Estimated leftover runtime: 18.0 [min]
# Setting of thresholds was sucessfull. Set to: [520, 520, 520, 520]
# Estimated leftover runtime: 16.0 [min]
# Setting of thresholds was sucessfull. Set to: [530, 530, 530, 530]
# Estimated leftover runtime: 14.0 [min]
# Setting of thresholds was sucessfull. Set to: [540, 540, 540, 540]
# Estimated leftover runtime: 12.0 [min]
# Setting of thresholds was sucessfull. Set to: [550, 550, 550, 550]
# Estimated leftover runtime: 10.0 [min]
# Setting of thresholds was sucessfull. Set to: [560, 560, 560, 560]
# Estimated leftover runtime: 8.0 [min]
# Setting of thresholds was sucessfull. Set to: [570, 570, 570, 570]
# Estimated leftover runtime: 6.0 [min]
# Setting of thresholds was sucessfull. Set to: [580, 580, 580, 580]
# Estimated leftover runtime: 4.0 [min]
# Setting of thresholds was sucessfull. Set to: [590, 590, 590, 590]
# Estimated leftover runtime: 2.0 [min]
# Setting of thresholds was sucessfull. Set to: [600, 600, 600, 600]
# Estimated leftover runtime: 0.0 [min]
